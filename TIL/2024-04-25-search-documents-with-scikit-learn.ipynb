# %% [markdown]
# ---
# title: Document Search with Scikit-Learn and TF-IDF
# pubDate: 2024-04-25
# shortDescription: Implementing keyword search on documents using scikit-learn's CountVectorizer for text analysis
# tags:
#   - Backend
# keywords: machine learning, text search, scikit-learn, nlp, document retrieval, vector search
# ---
#
# # Keyword search on a list of documents (with scikit-learn)

# %%
documents = [
  {"id": 1, "text": "Programming requires logical thinking and problem-solving skills."},
  {"id": 2, "text": "Learning to code improves problem-solving and logical thinking abilities."},
  {"id": 3, "text": "Logical thinking is essential for writing efficient code."},
  {"id": 4, "text": "Effective programming involves solving complex problems logically."},
  {"id": 5, "text": "Developing software enhances problem-solving and logical thinking."}
]

# %% [markdown]
# ## Convert the documents to a matrix of token counts

# %% [markdown]
# Install packages
#
#     pip install scikit-learn pandas numpy

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.DataFrame(documents)
df
# Out:
#    id                                               text
# 0   1  Programming requires logical thinking and prob...
# 1   2  Learning to code improves problem-solving and ...
# 2   3  Logical thinking is essential for writing effi...
# 3   4  Effective programming involves solving complex...
# 4   5  Developing software enhances problem-solving a...

# %%
df["text"].tolist()
# Out:
# ['Programming requires logical thinking and problem-solving skills.',
#  'Learning to code improves problem-solving and logical thinking abilities.',
#  'Logical thinking is essential for writing efficient code.',
#  'Effective programming involves solving complex problems logically.',
#  'Developing software enhances problem-solving and logical thinking.']

# %%
count_vectorizer = CountVectorizer(binary=True)
count_vectorizer.fit(df["text"].tolist())
count_vectorizer.get_feature_names_out()
# Out:
# array(['abilities', 'and', 'code', 'complex', 'developing', 'effective',
#        'efficient', 'enhances', 'essential', 'for', 'improves',
#        'involves', 'is', 'learning', 'logical', 'logically', 'problem',
#        'problems', 'programming', 'requires', 'skills', 'software',
#        'solving', 'thinking', 'to', 'writing'], dtype=object)

# %%
corpus = df['text'].tolist()
matrix = count_vectorizer.transform(corpus)
tokens = sorted(count_vectorizer.vocabulary_.keys(), key=lambda token: count_vectorizer.vocabulary_[token])
fit = pd.DataFrame(matrix.toarray(), columns=tokens)
fit["text"] = df["text"]
fit.set_index("text", inplace=True)
fit
# Out:
#                                                     abilities  and  code  \
# text
# Programming requires logical thinking and probl...          0    1     0
# Learning to code improves problem-solving and l...          1    1     1
# Logical thinking is essential for writing effic...          0    0     1
# Effective programming involves solving complex ...          0    0     0
# Developing software enhances problem-solving an...          0    1     0
#
#                                                     complex  developing  \
# text
# Programming requires logical thinking and probl...        0           0
# Learning to code improves problem-solving and l...        0           0
# Logical thinking is essential for writing effic...        0           0
# Effective programming involves solving complex ...        1           0
# Developing software enhances problem-solving an...        0           1
#
#                                                     effective  efficient  \
# text
# Programming requires logical thinking and probl...          0          0
# Learning to code improves problem-solving and l...          0          0
# Logical thinking is essential for writing effic...          0          1
# Effective programming involves solving complex ...          1          0
# Developing software enhances problem-solving an...          0          0
#
#                                                     enhances  essential  for  \
# text
# Programming requires logical thinking and probl...         0          0    0
# Learning to code improves problem-solving and l...         0          0    0
# Logical thinking is essential for writing effic...         0          1    1
# Effective programming involves solving complex ...         0          0    0
# Developing software enhances problem-solving an...         1          0    0
#
#                                                     ...  problem  problems  \
# text                                                ...
# Programming requires logical thinking and probl...  ...        1         0
# Learning to code improves problem-solving and l...  ...        1         0
# Logical thinking is essential for writing effic...  ...        0         0
# Effective programming involves solving complex ...  ...        0         1
# Developing software enhances problem-solving an...  ...        1         0
#
#                                                     programming  requires  \
# text
# Programming requires logical thinking and probl...            1         1
# Learning to code improves problem-solving and l...            0         0
# Logical thinking is essential for writing effic...            0         0
# Effective programming involves solving complex ...            1         0
# Developing software enhances problem-solving an...            0         0
#
#                                                     skills  software  solving  \
# text
# Programming requires logical thinking and probl...       1         0        1
# Learning to code improves problem-solving and l...       0         0        1
# Logical thinking is essential for writing effic...       0         0        0
# Effective programming involves solving complex ...       0         0        1
# Developing software enhances problem-solving an...       0         1        1
#
#                                                     thinking  to  writing
# text
# Programming requires logical thinking and probl...         1   0        0
# Learning to code improves problem-solving and l...         1   1        0
# Logical thinking is essential for writing effic...         1   0        1
# Effective programming involves solving complex ...         0   0        0
# Developing software enhances problem-solving an...         1   0        0
#
# [5 rows x 26 columns]

# %%
query_vector = count_vectorizer.transform(["logical thinking"])
a = matrix.dot(query_vector.T).todense()
fit["score"] = a.sum(axis=1)
fit.sort_values("score", ascending=False)
# Out:
#                                                     abilities  and  code  \
# text
# Programming requires logical thinking and probl...          0    1     0
# Learning to code improves problem-solving and l...          1    1     1
# Logical thinking is essential for writing effic...          0    0     1
# Developing software enhances problem-solving an...          0    1     0
# Effective programming involves solving complex ...          0    0     0
#
#                                                     complex  developing  \
# text
# Programming requires logical thinking and probl...        0           0
# Learning to code improves problem-solving and l...        0           0
# Logical thinking is essential for writing effic...        0           0
# Developing software enhances problem-solving an...        0           1
# Effective programming involves solving complex ...        1           0
#
#                                                     effective  efficient  \
# text
# Programming requires logical thinking and probl...          0          0
# Learning to code improves problem-solving and l...          0          0
# Logical thinking is essential for writing effic...          0          1
# Developing software enhances problem-solving an...          0          0
# Effective programming involves solving complex ...          1          0
#
#                                                     enhances  essential  for  \
# text
# Programming requires logical thinking and probl...         0          0    0
# Learning to code improves problem-solving and l...         0          0    0
# Logical thinking is essential for writing effic...         0          1    1
# Developing software enhances problem-solving an...         1          0    0
# Effective programming involves solving complex ...         0          0    0
#
#                                                     ...  problems  \
# text                                                ...
# Programming requires logical thinking and probl...  ...         0
# Learning to code improves problem-solving and l...  ...         0
# Logical thinking is essential for writing effic...  ...         0
# Developing software enhances problem-solving an...  ...         0
# Effective programming involves solving complex ...  ...         1
#
#                                                     programming  requires  \
# text
# Programming requires logical thinking and probl...            1         1
# Learning to code improves problem-solving and l...            0         0
# Logical thinking is essential for writing effic...            0         0
# Developing software enhances problem-solving an...            0         0
# Effective programming involves solving complex ...            1         0
#
#                                                     skills  software  solving  \
# text
# Programming requires logical thinking and probl...       1         0        1
# Learning to code improves problem-solving and l...       0         0        1
# Logical thinking is essential for writing effic...       0         0        0
# Developing software enhances problem-solving an...       0         1        1
# Effective programming involves solving complex ...       0         0        1
#
#                                                     thinking  to  writing  \
# text
# Programming requires logical thinking and probl...         1   0        0
# Learning to code improves problem-solving and l...         1   1        0
# Logical thinking is essential for writing effic...         1   0        1
# Developing software enhances problem-solving an...         1   0        0
# Effective programming involves solving complex ...         0   0        0
#
#                                                     score
# text
# Programming requires logical thinking and probl...      2
# Learning to code improves problem-solving and l...      2
# Logical thinking is essential for writing effic...      2
# Developing software enhances problem-solving an...      2
# Effective programming involves solving complex ...      0
#
# [5 rows x 27 columns]
